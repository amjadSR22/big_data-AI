# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gender = pd.read_csv("name_gender_dataset.csv")
gender
# Out:
#            Name Gender    Count   Probability
# 0         James      M  5304407  1.451679e-02
# 1          John      M  5260831  1.439753e-02
# 2        Robert      M  4970386  1.360266e-02
# 3       Michael      M  4579950  1.253414e-02
# 4       William      M  4226608  1.156713e-02
# ...         ...    ...      ...           ...
# 147264   Zylenn      M        1  2.736740e-09
# 147265   Zymeon      M        1  2.736740e-09
# 147266   Zyndel      M        1  2.736740e-09
# 147267   Zyshan      M        1  2.736740e-09
# 147268    Zyton      M        1  2.736740e-09
#
# [147269 rows x 4 columns]

# %%
gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147269 entries, 0 to 147268
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Name         147269 non-null  object
#  1   Gender       147269 non-null  object
#  2   Count        147269 non-null  int64
#  3   Probability  147269 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.5+ MB

# %%
# line plot # matplotlib
plt.figure(figsize=(10,5))# Appropriate figure size
plt.title('Relation between the count and probability') # title
plt.xlabel('Probability') # X label
plt.ylabel('Count') # y label
plt.plot(gender['Probability'], gender['Count']);
# Explain 
# the graph it's show direct relationship between Count and probability

# %%
gender_index = gender.iloc[0:100]
# the data took a lot of time to process that's why I took a small sample

# %%
#Bar Chart # matplotlib
plt.figure(figsize=(10,5)) # Size
plt.title('number of babies') # title
plt.xlabel('gender') # x label
plt.ylabel('count') # y label
plt.bar(gender_index['Gender'], gender_index['Count']);
# explain 
# the number of male from babies is more than female

# %%
#Scatter Plot # matplotlib
plt.figure(figsize=(10,5))
plt.scatter( gender['Probability'] , gender['Count']);
plt.title('The Realtion between Count and probability'); # title
plt.xlabel('Probability'); # xlabel
plt.ylabel('Count'); # ylabel
#explain 
# there a direct relationship between them
# also is seem like there something weird cause there no points at the middle

# %%
#number of female
num_f = (gender['Gender'] == 'F').sum()
num_f
# Out:
# 89749

# %%
#number of male
num_m = (gender['Gender'] == 'M').sum()
num_m
# Out:
# 57520

# %%
# pie chart # matplotlib  # seaborn help for customize the graph
plt.figure(figsize= (10,20)) # SIZE
plt.title('number of male and female') # title
num_gen = [num_f , num_m] # number of man and female
label = ['Female' , 'Male'] 
plt.pie(num_gen , labels= label);
plt.legend(); # legend
sns.set()
sns.color_palette('pastel');
# explain
# the number of female in all sample is greater than male

# %%
# Histogram plot # matplotlib
plt.figure(figsize=(10,5));
plt.hist(gender_index['Gender']);
plt.title("Number of male and female") # title
plt.xlabel('Gender'); # xlabel
plt.ylabel('Count'); # ylabel
#explain
#number of male more than female

# %%
#Boxplot # matplotlib
plt.figure(figsize=(10,5))
count = gender_index['Count'] 
prob = gender_index['Probability']
plt.boxplot([count,prob], labels= ('Count' , 'Probability')); 
plt.title('Statistical Information'); # title
# explain 
# is show some oultier 
# the number in Count is have skewed right distrbution # not sure about it 
# the number in prob cocentrated on mean
# I think I need more gragh and stat info to understand more about stat info

# %%
# line chart # seaborn
sns.set() # to make gragh more beatiful 
plt.figure(figsize=(10,5)) # size
plt.title("Relationship between Count and Probability") # title
sns.lineplot(y = gender_index['Count'], x = gender_index['Probability']); # xlabel and ylabel appear automatic
# explain 
# there direct relationship

# %%
# Bar Chart # seaborn 
plt.figure(figsize= (20,10)) # size
plt.title('Realtionship between count and probability')# title 
sns.barplot( x = gender_index['Count'], y = gender_index['Probability']); # xlabel and ylabel appear automatic
#explain 
# is show skewed left distrbution # the disturbution is more clear there than boxplot 
# is very useful to viz many of gragh

# %%
#Scatter Plot # seaborn 
plt.figure(figsize= (10,10)) # size
plt.title('Realtionship between count and probability')# title 
sns.scatterplot( x = gender_index['Count'], y = gender_index['Probability']);
#explain
#there a direct relationship between them

# %%
# Histogram # seaborn
plt.figure(figsize= (10,5)) # size
plt.title('Realtionship between count and probability')# title 
sns.histplot(x = gender_index['Probability'], y = gender_index['Count']); # xlabel # ylabel
#explain 
# I can't understand anything from graph for that I will not use it

# %%
# box plot # seaborn
plt.figure(figsize=(10,5)) # size 
plt.title('Statistical Information'); # title
sns.boxplot( data = gender , x = gender['Gender'] , y = gender['Count']);  # xlabel # ylabel
# explain
# is hard to understand this data # but is appear there outlier on female so maybe the data need some clean

# %%
plt.figure(figsize=(20,10));
plt.subplot(2,2,1);
sns.lineplot(y = gender_index['Count'], x = gender_index['Probability']);
plt.subplot(2,2,2);
sns.scatterplot( x = gender_index['Count'], y = gender_index['Probability']);
plt.subplot(2,2,3);
plt.pie(num_gen , labels= label);
plt.subplot(2,2,4);
plt.boxplot([count,prob], labels= ('Count' , 'Probability'));

# %%
#thank you
